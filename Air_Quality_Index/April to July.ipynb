# %%
import pandas as pd
df=pd.read_csv("us-embassy, kathmandu-air-qualityD.csv")

print(df)
# Out:
#            date PM25 PM10
# 0     12/1/2020  129   75
# 1     12/2/2020  108   79
# 2     12/3/2020  101   76
# 3     12/4/2020  113   74
# 4     12/5/2020  118   66
# ...         ...  ...  ...
# 1304        NaN  NaN  NaN
# 1305        NaN  NaN  NaN
# 1306        NaN  NaN  NaN
# 1307        NaN  NaN  NaN
# 1308        NaN  NaN  NaN
#
# [1309 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['date', 'PM25', 'PM10'], dtype='object')

# %%
#last three months AQI
df['date'] = pd.to_datetime(df.date)
mask = (df['date'] >'2020-04-01') & (df['date']  < '2020-07-01')

dfl = df.loc[mask]
dfl
# Out:
#           date PM25 PM10
# 177 2020-06-01   66   32
# 178 2020-06-02   50   39
# 179 2020-06-03   66   36
# 180 2020-06-04   79   17
# 181 2020-06-05   35   12
# ..         ...  ...  ...
# 263 2020-04-26   84   23
# 264 2020-04-27   67   26
# 265 2020-04-28   60   29
# 266 2020-04-29   64   28
# 267 2020-04-30   69   28
#
# [90 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

dates = dfl['date']

pm25 = dfl['PM25']
pm25 = [int(i) for i in pm25]

plt.figure(figsize=(10,8))

length = len(dates)

plt.plot(dates,pm25,color='green',label='April to July PM2.5 values')
plt.title('PM2.5 values from April to July of Kathmandu- US Embassy Station AQI Data')
plt.xlabel('Dates of Last April to July')
plt.ylabel('PM2.5 values')
plt.legend()
plt.show()

# %%
print(dates)
# Out:
# 177   2020-06-01
# 178   2020-06-02
# 179   2020-06-03
# 180   2020-06-04
# 181   2020-06-05
#          ...
# 263   2020-04-26
# 264   2020-04-27
# 265   2020-04-28
# 266   2020-04-29
# 267   2020-04-30
# Name: date, Length: 90, dtype: datetime64[ns]

# %%
dfl['PM25'] = [int(i) for i in dfl['PM25']]
print(dfl[dfl.PM25 == dfl.PM25.max()])
# Out:
#           date  PM25  PM10
# 249 2020-04-11   194    77
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dfl['PM10'] = [int(i) for i in dfl['PM10']]
print(dfl[dfl.PM10 == dfl.PM10.max()])
# Out:
#           date  PM25  PM10
# 248 2020-04-10   150    87
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
