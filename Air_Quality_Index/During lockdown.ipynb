# %%
import pandas as pd
df=pd.read_csv("us-embassy, kathmandu-air-quality .csv")

print(df)
# Out:
#             date  PM25  PM10
# 0      12/1/2020   129    75
# 1      12/2/2020   108    79
# 2      12/3/2020   101    76
# 3      12/4/2020   113    74
# 4      12/5/2020   118    66
# ...          ...   ...   ...
# 1305   10/8/2018     0    87
# 1306  10/19/2018     0    77
# 1307  10/20/2018     0    75
# 1308  10/21/2018     0    91
# 1309  10/22/2018     0   103
#
# [1310 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['date', 'PM25', 'PM10'], dtype='object')

# %%
#last three months AQI
df['date'] = pd.to_datetime(df.date)
mask = (df['date'] >='2020-03-01') & (df['date']  <= '2020-06-01')

dfl = df.loc[mask]
dfl
# Out:
#            date  PM25  PM10
# 178  2020-06-01    66    32
# 208  2020-05-01    61    27
# 209  2020-05-02    62    36
# 210  2020-05-03    71    28
# 211  2020-05-04    51     0
# ...         ...   ...   ...
# 295  2020-03-30    91    48
# 296  2020-03-31   117    45
# 1293 2020-03-17     0    21
# 1294 2020-03-18     0    22
# 1295 2020-03-19     0    18
#
# [93 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

dates = dfl['date']
pm25 = dfl['PM25']
pm25 = [int(i) for i in pm25]

plt.figure(figsize=(10,8))

length = len(dates)

plt.plot(dates,pm25,color='green',label='March to June PM2.5 values')
plt.title('PM2.5 values from March to June of Kathmandu- US Embassy Station AQI Data')
plt.xlabel('Dates of Last March to June')
plt.ylabel('PM2.5 values')
plt.legend()
plt.show()

# %%
dfl['PM25'] = [int(i) for i in dfl['PM25']]
print(dfl[dfl.PM25 == dfl.PM25.max()])
# Out:
#           date  PM25  PM10
# 249 2020-04-11   194    77
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dfl['PM10'] = [int(i) for i in dfl['PM10']]
print(dfl[dfl.PM10 == dfl.PM10.max()])
# Out:
#           date  PM25  PM10
# 248 2020-04-10   150    87
# c:\users\acer\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
